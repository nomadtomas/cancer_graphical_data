# %%
import pandas as pd 
from splinter import Browser
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import requests
import numpy as np
import json

# %%
#Browser setup
executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
browser = Browser("chrome")

# %%
base_url = "https://health.usnews.com/best-hospitals/rankings/cancer?page="
mini_url = "https://health.usnews.com"

# %%
soup = bs(browser.html, 'lxml')

# %%
list_ = [str(x) for x in list(range(1,10))]

# %%
for x in list_:
    print(base_url + x)

# %%
def dataframes(url):
    city = []
    browser.visit(url)
    soup = bs(browser.html, 'lxml')
    name = soup.find_all("h3", class_="block-flush heading-large")
    ranking = soup.find_all("span", class_="heading-small")
    score = soup.find_all("div", class_="text-strong text-tighter")
    web = soup.find_all(class_="search-match-card-view")
    
    names = [x.get_text(strip=True) for x in name]
    rankings = [x.get_text(strip=True) for x in ranking]
    scores = [x.get_text(strip=True) for x in score]
    info = soup.find_all("div", class_="block-tight")
    websites = [mini_url + x.a["href"] for x in web]
    
    for x in range(0,len(info[1:-1]),2):
        city.append(info[x].get_text(strip=True).split("|")[-1])
        
    df_names = pd.DataFrame(names)
    df_rankings = pd.DataFrame(rankings)
    df_scores = pd.DataFrame(scores)
    df_cities = pd.DataFrame(city[1:])
    df_web = pd.DataFrame(websites)
    
    df_1 = pd.merge(df_names, df_rankings, left_index=True, right_index=True)
    df_2 = pd.merge(df_1, df_scores, left_index=True, right_index=True)
    df_3 = pd.merge(df_2, df_cities, left_index=True, right_index=True)
    df = pd.merge(df_3, df_web, left_index=True, right_index=True)
    df.columns = ["name", "rank", "score", "cities", "websites"]
    return df

# %%
p1 = dataframes("https://health.usnews.com/best-hospitals/rankings/cancer?page=1")
p2 = dataframes("https://health.usnews.com/best-hospitals/rankings/cancer?page=2")
p3 = dataframes("https://health.usnews.com/best-hospitals/rankings/cancer?page=3")
p4 = dataframes("https://health.usnews.com/best-hospitals/rankings/cancer?page=4")
p5 = dataframes("https://health.usnews.com/best-hospitals/rankings/cancer?page=5")
p6 = dataframes("https://health.usnews.com/best-hospitals/rankings/cancer?page=6")
p7 = dataframes("https://health.usnews.com/best-hospitals/rankings/cancer?page=7")
p8 = dataframes("https://health.usnews.com/best-hospitals/rankings/cancer?page=8")
p9 = dataframes("https://health.usnews.com/best-hospitals/rankings/cancer?page=9")

# %%
m1 = p1.append(p2, ignore_index=True)
m2 = m1.append(p3, ignore_index=True)
m3 = m2.append(p4, ignore_index=True)
m4 = m3.append(p5, ignore_index=True)
m5 = m4.append(p6, ignore_index=True)
m6 = m5.append(p7, ignore_index=True)
m7 = m6.append(p8, ignore_index=True)
df = m7.append(p9, ignore_index=True)

# %%
df["num_rank"] = df.iloc[:,1].map(lambda x : x.split(' ')[0].split("#")[-1])
df["num_score"] = df.iloc[:,2].map(lambda x : x.split("/")[0])
df['city_name'] = df.iloc[:,3].map(lambda x : x.split(',')[0])
df['state'] = df.iloc[:,3].map(lambda x : x.split(',')[1].split(' ')[1])
df['zipcode'] = df.iloc[:,3].map(lambda x : x.split(',')[1].split(' ')[2])
df["num_rank"] = df["num_rank"].replace("High", 0).astype(int)
df["num_score"] = df["num_score"].astype(float)

# %%
df["num_rank"] = df["num_rank"].replace("High", 0).astype(int)
df["num_score"] = df["num_score"].astype(float)

# %%
df.to_csv("../cancer_graphical_data/data/hospital_ranking.csv", index=False)

# %%
names = df['name'].tolist()

# %%
lat = []
lng = []

for name in names:
    target_city = name
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
        'address={0}&key={1}').format(target_city, gkey)

    geo_data = requests.get(target_url).json()
    lat.append(geo_data['results'][0]['geometry']['viewport']['northeast']['lat'])
    lng.append(geo_data['results'][0]['geometry']['viewport']['northeast']['lng'])

# %%
df['lat'] = pd.DataFrame(lat)
df['lng'] = pd.DataFrame(lng)

# %%
df
# Out:
#                                                  name  \
# 0       University of Texas MD Anderson Cancer Center
# 1              Memorial Sloan-Kettering Cancer Center
# 2                                         Mayo Clinic
# 3       Dana-Farber/Brigham and Women's Cancer Center
# 4                                    Cleveland Clinic
# 5                              Johns Hopkins Hospital
# 6   Seattle Cancer Alliance/University of Washingt...
# 7   H. Lee Moffitt Cancer Center and Research Inst...
# 8                                 UCSF Medical Center
# 9   Hospitals of the University of Pennsylvania-Pe...
# 10                                Mayo Clinic-Phoenix
# 11                     Massachusetts General Hospital
# 12                     Northwestern Memorial Hospital
# 13             Stanford Health Care-Stanford Hospital
# 14                              Siteman Cancer Center
# 15  University of Michigan Hospitals-Michigan Medi...
# 16  USC Norris Cancer Hospital-Keck Medical Center...
# 17           University of Iowa Hospitals and Clinics
# 18                 Wake Forest Baptist Medical Center
# 19        Ohio State University James Cancer Hospital
# 20    City of Hope Helford Clinical Research Hospital
# 21                                UCLA Medical Center
# 22                        UPMC Presbyterian Shadyside
# 23              MUSC Health-University Medical Center
# 24  New York-Presbyterian Hospital-Columbia and Co...
# 25  Jefferson Health-Thomas Jefferson University H...
# 26           UCHealth University of Colorado Hospital
# 27                                      OHSU Hospital
# 28         University Hospitals Seidman Cancer Center
# 29                    Mayo Clinic Hospital in Florida
# ..                                                ...
# 59       University of Alabama at Birmingham Hospital
# 60                            Fox Chase Cancer Center
# 61                          Emory University Hospital
# 62          Nebraska Medicine-Nebraska Medical Center
# 63                   Loyola University Medical Center
# 64                           Carolinas Medical Center
# 65                                 UCI Medical Center
# 66                             Karmanos Cancer Center
# 67             Presbyterian-St. Luke's Medical Center
# 68                           Cleveland Clinic Florida
# 69                             Queen's Medical Center
# 70                 West Virginia University Hospitals
# 71  Dan L Duncan Comprehensive Cancer Center at Ba...
# 72                          Montefiore Medical Center
# 73                                Medical City Dallas
# 74                 Advocate Lutheran General Hospital
# 75           Banner University Medical Center Phoenix
# 76                             Ochsner Medical Center
# 77               Hackensack University Medical Center
# 78                Hoag Memorial Hospital Presbyterian
# 79                                Lenox Hill Hospital
# 80                 Cleveland Clinic Fairview Hospital
# 81            Kaiser Permanente Downey Medical Center
# 82             MedStar Georgetown University Hospital
# 83                    University of Illinois Hospital
# 84            University of Cincinnati Medical Center
# 85                   Sentara Norfolk General Hospital
# 86                                Henry Ford Hospital
# 87            Robert Wood Johnson University Hospital
# 88                   Aurora St. Luke's Medical Center
#
#                                rank      score                        cities  \
# 0      #1 in Adult Cancer Hospitals  100.0/100        Houston, TX 77030-4000
# 1      #2 in Adult Cancer Hospitals   97.4/100       New York, NY 10065-6007
# 2      #3 in Adult Cancer Hospitals   95.3/100      Rochester, MN 55902-1906
# 3      #4 in Adult Cancer Hospitals   83.0/100              Boston, MA 02215
# 4      #5 in Adult Cancer Hospitals   80.9/100      Cleveland, OH 44195-5108
# 5      #6 in Adult Cancer Hospitals   80.3/100      Baltimore, MD 21287-2182
# 6      #7 in Adult Cancer Hospitals   78.5/100        Seattle, WA 98109-4405
# 7      #8 in Adult Cancer Hospitals   76.6/100          Tampa, FL 33612-9497
# 8      #8 in Adult Cancer Hospitals   76.6/100  San Francisco, CA 94143-0296
# 9     #10 in Adult Cancer Hospitals   75.8/100   Philadelphia, PA 19104-4206
# 10    #11 in Adult Cancer Hospitals   74.1/100        Phoenix, AZ 85054-4502
# 11    #12 in Adult Cancer Hospitals   72.6/100         Boston, MA 02114-2696
# 12    #12 in Adult Cancer Hospitals   72.6/100        Chicago, IL 60611-2908
# 13    #14 in Adult Cancer Hospitals   72.4/100            Stanford, CA 94305
# 14    #15 in Adult Cancer Hospitals   72.3/100    Saint Louis, MO 63110-1003
# 15    #15 in Adult Cancer Hospitals   72.3/100           Ann Arbor, MI 48109
# 16    #17 in Adult Cancer Hospitals   71.7/100    Los Angeles, CA 90089-0112
# 17    #18 in Adult Cancer Hospitals   70.2/100      Iowa City, IA 52242-1009
# 18    #19 in Adult Cancer Hospitals   70.0/100  Winston-Salem, NC 27157-0001
# 19    #20 in Adult Cancer Hospitals   69.9/100       Columbus, OH 43210-1280
# 20    #21 in Adult Cancer Hospitals   69.4/100         Duarte, CA 91010-3012
# 21    #21 in Adult Cancer Hospitals   69.4/100    Los Angeles, CA 90095-8358
# 22    #23 in Adult Cancer Hospitals   68.9/100     Pittsburgh, PA 15213-2536
# 23    #24 in Adult Cancer Hospitals   68.7/100     Charleston, SC 29425-8905
# 24    #25 in Adult Cancer Hospitals   68.5/100       New York, NY 10065-4870
# 25    #26 in Adult Cancer Hospitals   68.4/100   Philadelphia, PA 19107-5084
# 26    #26 in Adult Cancer Hospitals   68.4/100         Aurora, CO 80045-2545
# 27    #28 in Adult Cancer Hospitals   67.9/100       Portland, OR 97239-3098
# 28    #28 in Adult Cancer Hospitals   67.9/100      Cleveland, OH 44106-1716
# 29    #30 in Adult Cancer Hospitals   67.8/100   Jacksonville, FL 32224-1865
# ..                              ...        ...                           ...
# 59  High Performing in Adult Cancer   60.0/100     Birmingham, AL 35249-1900
# 60  High Performing in Adult Cancer   59.9/100   Philadelphia, PA 19111-2434
# 61  High Performing in Adult Cancer   59.8/100             Atlanta, GA 30322
# 62  High Performing in Adult Cancer   59.5/100               Omaha, NE 68105
# 63  High Performing in Adult Cancer   59.1/100        Maywood, IL 60153-3328
# 64  High Performing in Adult Cancer   58.8/100      Charlotte, NC 28203-5871
# 65  High Performing in Adult Cancer   58.3/100         Orange, CA 92868-3298
# 66  High Performing in Adult Cancer   58.1/100        Detroit, MI 48201-2013
# 67  High Performing in Adult Cancer   57.3/100         Denver, CO 80218-1281
# 68  High Performing in Adult Cancer   57.1/100         Weston, FL 33331-3602
# 69  High Performing in Adult Cancer   57.0/100       Honolulu, HI 96813-2499
# 70  High Performing in Adult Cancer   57.0/100     Morgantown, WV 26506-4749
# 71  High Performing in Adult Cancer   56.9/100        Houston, TX 77030-2697
# 72  High Performing in Adult Cancer   56.4/100          Bronx, NY 10467-2401
# 73  High Performing in Adult Cancer   56.2/100         Dallas, TX 75230-2598
# 74  High Performing in Adult Cancer   56.0/100     Park Ridge, IL 60068-1174
# 75  High Performing in Adult Cancer   55.9/100        Phoenix, AZ 85006-2666
# 76  High Performing in Adult Cancer   55.9/100    New Orleans, LA 70121-2429
# 77  High Performing in Adult Cancer   55.8/100     Hackensack, NJ 07601-1914
# 78  High Performing in Adult Cancer   55.7/100  Newport Beach, CA 92663-4120
# 79  High Performing in Adult Cancer   55.6/100       New York, NY 10075-1850
# 80  High Performing in Adult Cancer   54.9/100      Cleveland, OH 44111-5656
# 81  High Performing in Adult Cancer   54.6/100         Downey, CA 90242-2812
# 82  High Performing in Adult Cancer   54.6/100     Washington, DC 20007-2197
# 83  High Performing in Adult Cancer   54.6/100        Chicago, IL 60612-7232
# 84  High Performing in Adult Cancer   54.5/100     Cincinnati, OH 45219-2316
# 85  High Performing in Adult Cancer   54.3/100        Norfolk, VA 23507-1904
# 86  High Performing in Adult Cancer   54.2/100        Detroit, MI 48202-2608
# 87  High Performing in Adult Cancer   53.9/100  New Brunswick, NJ 08901-1928
# 88  High Performing in Adult Cancer   53.5/100      Milwaukee, WI 53215-4330
#
#                                              websites num_rank num_score  \
# 0   https://health.usnews.com/best-hospitals/area/...        1     100.0
# 1   https://health.usnews.com/best-hospitals/area/...        2      97.4
# 2   https://health.usnews.com/best-hospitals/area/...        3      95.3
# 3   https://health.usnews.com/best-hospitals/area/...        4      83.0
# 4   https://health.usnews.com/best-hospitals/area/...        5      80.9
# 5   https://health.usnews.com/best-hospitals/area/...        6      80.3
# 6   https://health.usnews.com/best-hospitals/area/...        7      78.5
# 7   https://health.usnews.com/best-hospitals/area/...        8      76.6
# 8   https://health.usnews.com/best-hospitals/area/...        8      76.6
# 9   https://health.usnews.com/best-hospitals/area/...       10      75.8
# 10  https://health.usnews.com/best-hospitals/area/...       11      74.1
# 11  https://health.usnews.com/best-hospitals/area/...       12      72.6
# 12  https://health.usnews.com/best-hospitals/area/...       12      72.6
# 13  https://health.usnews.com/best-hospitals/area/...       14      72.4
# 14  https://health.usnews.com/best-hospitals/area/...       15      72.3
# 15  https://health.usnews.com/best-hospitals/area/...       15      72.3
# 16  https://health.usnews.com/best-hospitals/area/...       17      71.7
# 17  https://health.usnews.com/best-hospitals/area/...       18      70.2
# 18  https://health.usnews.com/best-hospitals/area/...       19      70.0
# 19  https://health.usnews.com/best-hospitals/area/...       20      69.9
# 20  https://health.usnews.com/best-hospitals/area/...       21      69.4
# 21  https://health.usnews.com/best-hospitals/area/...       21      69.4
# 22  https://health.usnews.com/best-hospitals/area/...       23      68.9
# 23  https://health.usnews.com/best-hospitals/area/...       24      68.7
# 24  https://health.usnews.com/best-hospitals/area/...       25      68.5
# 25  https://health.usnews.com/best-hospitals/area/...       26      68.4
# 26  https://health.usnews.com/best-hospitals/area/...       26      68.4
# 27  https://health.usnews.com/best-hospitals/area/...       28      67.9
# 28  https://health.usnews.com/best-hospitals/area/...       28      67.9
# 29  https://health.usnews.com/best-hospitals/area/...       30      67.8
# ..                                                ...      ...       ...
# 59  https://health.usnews.com/best-hospitals/area/...     High      60.0
# 60  https://health.usnews.com/best-hospitals/area/...     High      59.9
# 61  https://health.usnews.com/best-hospitals/area/...     High      59.8
# 62  https://health.usnews.com/best-hospitals/area/...     High      59.5
# 63  https://health.usnews.com/best-hospitals/area/...     High      59.1
# 64  https://health.usnews.com/best-hospitals/area/...     High      58.8
# 65  https://health.usnews.com/best-hospitals/area/...     High      58.3
# 66  https://health.usnews.com/best-hospitals/area/...     High      58.1
# 67  https://health.usnews.com/best-hospitals/area/...     High      57.3
# 68  https://health.usnews.com/best-hospitals/area/...     High      57.1
# 69  https://health.usnews.com/best-hospitals/area/...     High      57.0
# 70  https://health.usnews.com/best-hospitals/area/...     High      57.0
# 71  https://health.usnews.com/best-hospitals/area/...     High      56.9
# 72  https://health.usnews.com/best-hospitals/area/...     High      56.4
# 73  https://health.usnews.com/best-hospitals/area/...     High      56.2
# 74  https://health.usnews.com/best-hospitals/area/...     High      56.0
# 75  https://health.usnews.com/best-hospitals/area/...     High      55.9
# 76  https://health.usnews.com/best-hospitals/area/...     High      55.9
# 77  https://health.usnews.com/best-hospitals/area/...     High      55.8
# 78  https://health.usnews.com/best-hospitals/area/...     High      55.7
# 79  https://health.usnews.com/best-hospitals/area/...     High      55.6
# 80  https://health.usnews.com/best-hospitals/area/...     High      54.9
# 81  https://health.usnews.com/best-hospitals/area/...     High      54.6
# 82  https://health.usnews.com/best-hospitals/area/...     High      54.6
# 83  https://health.usnews.com/best-hospitals/area/...     High      54.6
# 84  https://health.usnews.com/best-hospitals/area/...     High      54.5
# 85  https://health.usnews.com/best-hospitals/area/...     High      54.3
# 86  https://health.usnews.com/best-hospitals/area/...     High      54.2
# 87  https://health.usnews.com/best-hospitals/area/...     High      53.9
# 88  https://health.usnews.com/best-hospitals/area/...     High      53.5
#
#         city_name state     zipcode         lng        lat
# 0         Houston    TX  77030-4000  -95.395714  29.707933
# 1        New York    NY  10065-6007  -73.954635  40.765450
# 2       Rochester    MN  55902-1906  -81.439602  30.265439
# 3          Boston    MA       02215  -71.106831  42.338800
# 4       Cleveland    OH  44195-5108  -81.619631  41.504002
# 5       Baltimore    MD  21287-2182  -76.591387  39.298087
# 6         Seattle    WA  98109-4405 -122.335321  47.714120
# 7           Tampa    FL  33612-9497  -82.419766  28.065447
# 8   San Francisco    CA  94143-0296 -122.456460  37.764400
# 9    Philadelphia    PA  19104-4206  -75.197771  39.959682
# 10        Phoenix    AZ  85054-4502 -111.955101  33.660401
# 11         Boston    MA  02114-2696  -71.067274  42.364831
# 12        Chicago    IL  60611-2908  -87.619961  41.895980
# 13       Stanford    CA       94305 -122.173636  37.434288
# 14    Saint Louis    MO  63110-1003  -90.262041  38.639851
# 15      Ann Arbor    MI       48109  -83.736875  42.279393
# 16    Los Angeles    CA  90089-0112 -118.203312  34.062646
# 17      Iowa City    IA  52242-1009  -91.546533  41.660242
# 18  Winston-Salem    NC  27157-0001  -80.267216  36.091145
# 19       Columbus    OH  43210-1280  -83.018280  39.996321
# 20         Duarte    CA  91010-3012 -117.971151  34.130454
# 21    Los Angeles    CA  90095-8358 -118.444969  34.067628
# 22     Pittsburgh    PA  15213-2536  -79.959271  40.444037
# 23     Charleston    SC  29425-8905  -79.948035  32.786070
# 24       New York    NY  10065-4870  -73.952817  40.767068
# 25   Philadelphia    PA  19107-5084  -75.156555  39.951043
# 26         Aurora    CO  80045-2545 -104.840566  39.743832
# 27       Portland    OR  97239-3098 -122.683603  45.500582
# 28      Cleveland    OH  44106-1716  -81.605161  41.506688
# 29   Jacksonville    FL  32224-1865  -81.439602  30.265439
# ..            ...   ...         ...         ...        ...
# 59     Birmingham    AL  35249-1900  -86.801740  33.507919
# 60   Philadelphia    PA  19111-2434  -75.089207  40.072281
# 61        Atlanta    GA       30322  -84.320830  33.793387
# 62          Omaha    NE       68105  -95.975754  41.257760
# 63        Maywood    IL  60153-3328  -87.834131  41.861984
# 64      Charlotte    NC  28203-5871  -80.837503  35.204926
# 65         Orange    CA  92868-3298 -117.888073  33.789005
# 66        Detroit    MI  48201-2013  -83.055827  42.353545
# 67         Denver    CO  80218-1281 -104.964439  39.748357
# 68         Weston    FL  33331-3602  -80.363642  26.083078
# 69       Honolulu    HI  96813-2499 -157.852360  21.309619
# 70     Morgantown    WV  26506-4749  -79.955997  39.654800
# 71        Houston    TX  77030-2697  -95.393424  29.701487
# 72          Bronx    NY  10467-2401  -73.878366  40.882003
# 73         Dallas    TX  75230-2598  -96.772253  32.913115
# 74     Park Ridge    IL  60068-1174  -87.845770  42.039977
# 75        Phoenix    AZ  85006-2666 -112.056535  33.466316
# 76    New Orleans    LA  70121-2429  -90.998633  30.444179
# 77     Hackensack    NJ  07601-1914  -74.054633  40.885409
# 78  Newport Beach    CA  92663-4120 -117.928488  33.625754
# 79       New York    NY  10075-1850  -73.959766  40.775145
# 80      Cleveland    OH  44111-5656  -81.821904  41.451409
# 81         Downey    CA  90242-2812 -118.126967  33.920204
# 82     Washington    DC  20007-2197  -77.073820  38.912813
# 83        Chicago    IL  60612-7232  -87.669747  41.870781
# 84     Cincinnati    OH  45219-2316  -84.502024  39.139102
# 85        Norfolk    VA  23507-1904  -76.301884  36.863650
# 86        Detroit    MI  48202-2608  -83.083996  42.368856
# 87  New Brunswick    NJ  08901-1928  -74.448260  40.496616
# 88      Milwaukee    WI  53215-4330  -87.949730  42.991900
#
# [89 rows x 12 columns]
