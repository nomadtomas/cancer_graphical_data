# %%
import pandas as pd 
from splinter import Browser
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import requests
import numpy as np
import pymongo

# %%
url = "https://seer.cancer.gov/statfacts/html/urinb.html"

# %%
soup = bs(response.text, 'lxml')

# %%
response = requests.get(url)

# %%
pd.read_html(url)[0]
# Out:
#     Year New Cases - SEER 9               New Cases - SEER 13                \
#     Year           Observed Modeled Trend            Observed Modeled Trend
# 0   1975              19.31         19.38                   -             -
# 1   1976              19.69         19.51                   -             -
# 2   1977              18.99         19.65                   -             -
# 3   1978              19.99         19.78                   -             -
# 4   1979              19.98         19.92                   -             -
# 5   1980              20.42         20.06                   -             -
# 6   1981              20.69         20.20                   -             -
# 7   1982              20.08         20.34                   -             -
# 8   1983              20.04         20.48                   -             -
# 9   1984              20.85         20.63                   -             -
# ...

# %%
pd.read_html(url)[1]
# Out:
#                                         Stage Percent of Cases  \
# 0  In Situ Only in Originating Layer of Cells              51%
# 1          Localized Confined to Primary Site              34%
# 2     Regional Spread to Regional Lymph Nodes               7%
# 3             Distant Cancer Has Metastasized               5%
# 4                            Unknown Unstaged               3%
#
#   5-Year Relative Survival
# 0                    95.8%
# 1                    69.5%
# 2                    36.3%
# 3                     4.6%
# 4                    47.3%

# %%
pd.read_html(url)[2]
# Out:
#    Rank          Common Types of Cancer  Estimated NewCases 2019  \
# 0   1.0          Breast Cancer (Female)                   268600
# 1   2.0        Lung and Bronchus Cancer                   228150
# 2   3.0                 Prostate Cancer                   174650
# 3   4.0               Colorectal Cancer                   145600
# 4   5.0            Melanoma of the Skin                    96480
# 5   6.0                  Bladder Cancer                    80470
# 6   7.0            Non-Hodgkin Lymphoma                    74200
# 7   8.0  Kidney and Renal Pelvis Cancer                    73820
# 8   9.0                  Uterine Cancer                    61880
# 9  10.0                        Leukemia                    61780
#
#    EstimatedDeaths 2019
# 0                 41760
# 1                142670
# 2                 31620
# 3                 51020
# 4                  7230
# 5                 17670
# 6                 19970
# 7                 14770
# ...
